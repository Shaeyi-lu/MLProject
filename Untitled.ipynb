# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\miche\anaconda3\lib\site-packages (2.22.1)
# Requirement already satisfied: six>=1.15.0 in c:\users\miche\anaconda3\lib\site-packages (from spotipy) (1.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\miche\anaconda3\lib\site-packages (from spotipy) (1.26.15)
# Requirement already satisfied: requests>=2.25.0 in c:\users\miche\anaconda3\lib\site-packages (from spotipy) (2.28.2)
# Requirement already satisfied: redis>=3.5.3 in c:\users\miche\anaconda3\lib\site-packages (from spotipy) (4.5.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\miche\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\miche\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\miche\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.0.1)
# Requirement already satisfied: async-timeout>=4.0.2; python_version <= "3.11.2" in c:\users\miche\anaconda3\lib\site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Authentication - without user
client_credentials_manager = SpotifyClientCredentials(client_id='d6894d98cd0740a7ade73ab52c1e10c8', client_secret='2ca47d2ed51e4201836d6b123f31eafb')
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f&nd=1"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
track_url=[]
track_name=[]
artist_name=[]
track_pop=[]
artist_pop=[]
artist_genres=[]
album=[]

for track in sp.playlist_tracks(playlist_URI)["items"]:
    #URI
    track_url.append(track["track"]["uri"])
    
    #Track name
    track_name.append(track["track"]["name"])
    
    #Main Artist
    artist_uri=track["track"]["artists"][0]["uri"]
    artist_info=sp.artist(artist_uri)
    
    #Name, popularity, genre
    artist_name.append(track["track"]["artists"][0]["name"])
    artist_pop.append(artist_info["popularity"])
    artist_genres.append(artist_info["genres"])
    
    #Album
    album.append(track["track"]["album"]["name"])
    
    #Popularity of the track
    track_pop.append(track["track"]["popularity"])

# %%
import pandas as pd

# %%
track_dataframe = pd.DataFrame({'track_url':track_url, 'artist_name' : artist_name, 'track_name' : track_name, 'track_pop' : track_pop, 'popularity' : artist_pop, 'genre' : artist_genres,})
print(track_dataframe.shape)
track_dataframe.head(20)
# Out:
# (50, 6)
#                                track_url      artist_name  \
# 0   spotify:track:4DHcnVTT87F0zZhRPYmZ3B      Miley Cyrus
# 1   spotify:track:0DWdj2oZMBFSzRsi2Cvfzf          KAROL G
# 2   spotify:track:1Qrg8KqiBpW07V7PNxwwwL              SZA
# 3   spotify:track:6AQbmUe0Qwf5PZnt4HmTXv   PinkPantheress
# 4   spotify:track:4W4fNrZYkobj539TOWsLO2       The Weeknd
# 5   spotify:track:4Dvkj6JhhA12EX05fT7y2e     Harry Styles
# 6   spotify:track:4nrPB8O7Y7wsOCJdgXkthe         Bizarrap
# 7   spotify:track:2dHHgzDwk4BJdRwy9uXhTO     Metro Boomin
# 8   spotify:track:4FAKtPVycI4DxoOHC01YqD           Yandel
# 9   spotify:track:3dnP0JxCgygwQH9Gm7q7nb   Eslabon Armado
# 10  spotify:track:0WtM2NBVQNNJLh6scP13H8             Rema
# 11  spotify:track:4P9Q0GojKVXpRTJCaL3kyy     Taylor Swift
# 12  spotify:track:0V3wPSX9ygBnCm8psDIegu     Taylor Swift
# 13  spotify:track:59hBR0BCtJsfIbV9VzCVAp            Jimin
# 14  spotify:track:0NZPBYD5qbEWRs3PrGiRkT        Sam Smith
# 15  spotify:track:2LBqCSwhJGcFQeTHMVGwy3       The Weeknd
# 16  spotify:track:4uUG5RXrOk84mYEfFvj3cK     David Guetta
# 17  spotify:track:3tt9i3Hhzq84dPS8H7iSiJ    Manuel Turizo
# 18  spotify:track:55ZATsjPlTeSTNJOuW90pW  Cartel De Santa
# 19  spotify:track:78Sw5GDo6AlGwTwanjXbGh             d4vd
#
#                                   track_name  track_pop  popularity  \
# 0                                    Flowers         87          92
# 1                                        TQG         97          94
# 2                                  Kill Bill         94          94
# 3                         Boy's a liar Pt. 2         97          85
# 4   Die For You (with Ariana Grande) - Remix         81          98
# 5                                  As It Was         91          90
# 6      Shakira: Bzrp Music Sessions, Vol. 53         97          88
# 7     Creepin' (with The Weeknd & 21 Savage)         96          91
# 8                                 Yandel 150         89          83
# 9                            Ella Baila Sola         90          82
# 10             Calm Down (with Selena Gomez)         94          83
# 11         All Of The Girls You Loved Before         88         100
# 12                                 Anti-Hero         93         100
# 13                          Set Me Free Pt.2         88          84
# 14                 Unholy (feat. Kim Petras)         86          88
# 15                               Die For You         90          98
# 16                           I'm Good (Blue)         94          90
# 17                                La Bachata         78          86
# 18                              Shorty Party         90          83
# 19                              Here With Me         93          83
#
#                                                 genre
# 0                                               [pop]
# 1    [reggaeton, reggaeton colombiano, urbano latino]
# 2                                          [pop, r&b]
# 3                                                  []
# 4      [canadian contemporary r&b, canadian pop, pop]
# 5                                               [pop]
# 6   [argentine hip hop, pop venezolano, trap argen...
# 7                                               [rap]
# 8           [latin hip hop, reggaeton, urbano latino]
# 9   [corrido, corridos tumbados, nueva musica mexi...
# 10                                     [nigerian pop]
# 11                                              [pop]
# 12                                              [pop]
# 13                                                 []
# 14                                      [pop, uk pop]
# 15     [canadian contemporary r&b, canadian pop, pop]
# 16         [big room, dance pop, edm, pop, pop dance]
# 17  [colombian pop, latin pop, reggaeton, reggaeto...
# 18                   [latin hip hop, mexican hip hop]
# 19                                      [bedroom pop]
